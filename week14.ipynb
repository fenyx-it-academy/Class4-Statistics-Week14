# %%
import pandas as pd
import numpy as ny
import seaborn as sns
import matplotlib.pyplot as plt
#1
titanic_data=sns.load_dataset("titanic")
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
Elimizdeki verilerin sınıfları;
Survived: hayatta kalma(0 = Hayır, 1 =Evet)
Pclass: pclass : Sosyo-ekonomik durum için bir temsilci (SES)
1. = Üst
2. = Orta
3. = Alt
Sex: Cinsiyet
Age: Yas
Sibsp: Titanik’teki kardeş/eş sayısı
Parch:Titanik’teki ebeveynlerin/çocukların sayısı
Fare: ücret
Embarked: Biniş limanı
Class:    Sinif
Ticket:   Bilet numarası
Embark_town: Binis sehri

# %%
#2
titanic_data.corr()
#the highest correlation between parch and sibsp
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
#3
titanic_data.fare.max()
# Out:
# 512.3292

# %%
titanic_data["fare"].min()
# Out:
# 0.0

# %%
titanic_data.fare.mean()
# Out:
# 32.2042079685746

# %%
titanic_data.fare.mode()
# Out:
# 0    8.05
# dtype: float64

# %%
titanic_data["fare"].median()
# Out:
# 14.4542

# %%
sns.boxplot(x=df_titanic["fare"]);

# %%
penguins_data = sns.load_dataset ("penguins")
penguins_data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins_data.corr()
#the highest correlation between flipper_length_mm and body_mass_g
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.scatterplot(x="flipper_length_mm",y="body_mass_g",data=penguins_data);

# %%
penguins_data.bill_length_mm.mean()
# Out:
# 43.92192982456142

# %%
penguins_data.bill_length_mm.min()
# Out:
# 32.1

# %%
penguins_data.bill_length_mm.max()
# Out:
# 59.6

# %%
penguins_data.bill_length_mm.mode()
# Out:
# 0    41.1
# dtype: float64

# %%
penguins_data.bill_length_mm.median()
# Out:
# 44.45

# %%
sns.boxplot(x=penguins_data["bill_length_mm"]);

# %%
sns.lmplot(x='bill_length_mm',y='bill_depth_mm',data=penguins_data);
#Standart Sapma data larin ne kadar tutarli yani ne kadar birlerlerine yakin veya uzak oldugunu saptamamiza yardimci olur.
# asagidaki Standart sapma grafiginde bill_length_mm ve  bill_depth_mm data larinin tutarsiz oldugu standart sapmanin coklugundan belli oluyor.

# %%
sns.lmplot(x='bill_length_mm',y='flipper_length_mm',data=penguins_data);
#Asagidaki grafikte bill_length_mm ve flipper_length_mm arasindaki standart sapma daha az sekilde gorulmustur. Data lar daha birlerine yakindir.

# %%
sns.lmplot(x='bill_length_mm',y='body_mass_g',data=penguins_data);
# Asagidaki standart sapma grafiginde bill_length_mm ve body_mass_g arasindaki datalarin standart sapmasi gosterilmistir. yukardaki standart sapmaya gore daha   #tutarsiz oldugu gorulur.
