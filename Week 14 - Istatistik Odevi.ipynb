# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
veri = sns.load_dataset ("titanic")
veri
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 1-Survived : Titanic gemisinde hayatta kalanlar 1 , hayatta kalmayanlar 0
# 2-Pclass   :  Ekonomi statüsüdür
#               1st = Upper
#               2nd = Middle
#               3rd = Lower
# 3-Sex : Male/Female
# 4-Age : Yolcuların Yaşları
# 5-Sibsp : kardes (1 or 0)
# 6-Parch : ebeveyn/çocuk (1 or 0)
# 7-Fare : Bilet fiyatı
# 8-Embarked: Liman isimleri (C, Q, S)
#             C = Cherbourg, Q = Queenstown, S = Southampton
# 9-class: yolcuların sınıfını gösterir
# 10-who: erkek mi, kadın mı yoksa çocuk mu olduğunu gösterir
# 11-adult_male: yolcunun yetişkin bir erkek olup olmadığına bakılmaksızın verileri
# 12-deck: yolcu kabininin ilk harfi
# 13-embark_town: başlatılan sütunun açık gösterisi
# 14-alive :yolcunun hayatta kalıp kalmadığını gösterir. (boolean)

# %%
veri.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
# Korelasyon ie ilgili aciklama:
#     sibsp ile alone arasindaki korelasyon -0.58 dir ve yuksek bir degerdir
#     parch ile alone arasindaki korelasyoon -0.58 dir ve yuksek bir degerdir

# %%
veri.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
veri['fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
veri['fare'].mode()
# Out:
# 0    8.05
# dtype: float64

# %%
veri['fare'].median()
# Out:
# 14.4542

# %%
# 1-Sadece ucret (fare) ait olan max ve min (512.32 ve 0) degerler
# 2-Sadece ucret (fare) ait olan mean degeri 32.20
# 3-Sadece ucret (fare) ait olan mode degeri 8.05
# 3-Sadece ucret (fare) ait olan median degeri 14.45

# %%
sns.boxplot(x=veri["fare"])

# %%
data = sns.load_dataset ("penguins")
data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
data['bill_length_mm'].describe()
# Out:
# count    342.000000
# mean      43.921930
# std        5.459584
# min       32.100000
# 25%       39.225000
# 50%       44.450000
# 75%       48.500000
# max       59.600000
# Name: bill_length_mm, dtype: float64

# %%
data['bill_length_mm'].mode()
# Out:
# 0    41.1
# dtype: float64

# %%
data['bill_length_mm'].median()
# Out:
# 44.45

# %%
# 1-Sadece bill_length_mm ait olan max ve min (59.60 ve 32.10) degerler
# 2-Sadece bill_length_mm (fare) ait olan mean degeri 43.92
# 3-Sadece bill_length_mm (fare) ait olan mode degeri 41.10
# 3-Sadece bill_length_mm (fare) ait olan median degeri 44.45

# %%
sns.boxplot(x=data["bill_length_mm"])
# Out:
# <AxesSubplot:xlabel='bill_length_mm'>

# %%
# bill_length_mm ait yorum:
# - Mavi kisim bize median gosteri sol taraf minumum degeri sag taraf ise maksimum degeri gostermektedir.
# - Box plotlarda ilk başta gözümüze çarpan bill_length_mm normal bir dağılım izlenimi vermesi.Cunku daire
# seklinde outlier degerler yoktur.
